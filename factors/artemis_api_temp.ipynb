# %%
import os
import requests

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from datetime import datetime
from artemis import Artemis
import snowflake.connector



API_KEY = os.getenv("ARTEMIS_API_KEY")

client = Artemis(api_key=API_KEY)
# Out:
# /Users/varun/github/gokustats-back-end/venv-factor-models/lib/python3.9/site-packages/snowflake/connector/vendored/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
assets_data = client.asset.list_asset_symbols()
coin_names = [asset.get("title") for asset in assets_data["assets"] if asset.get("title")]

# %% [markdown]
# # Signals to try
#
# # Long
# # Increasing DAU + Increasing Fees + Prices Lagging (fundamental improvement that's not yet priced in)
# # Rising market share + Low Volume / MC (Quality of Coin)
# # High Fee Yield + Positiive Stablecoin Inflows to the Chain
#
# # Short
# # High Volume / MC + Low Volume Efficiency (Possible Wash Trading / Pump)
# # Declining DAU + Rising Price (Speculation vs. Reality Divergence)
# # Falling Fees + Rising Price (Unsustainable)
#
#
#
#
# How to use metrics:
# Focus on what works:
# - pure momentum strategies
# - narrative / sentiment tracking
# - market structure (liquidity, order flow)
# - technical patterns
#
# How to use fundamentals:
# - Risk Management (Create threshold cutoffs for fundamentals) - avoid fundamentally broken projects
# - Position sizing (Size up on fundamental + momentum alignment)
# - Sector rotation (Fundamentals for allocation, not selection of specific coin)

# %%
conn = snowflake.connector.connect(
    user=os.getenv('SYSTEM_SNOWFLAKE_USER'),
    account=os.getenv('SNOWFLAKE_ACCOUNT'),
    warehouse=os.getenv('ANALYSIS_MED'),
    authenticator='externalbrowser',
)
cur = conn.cursor()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 conn = snowflake.connector.connect(
#       2     user=os.getenv('SYSTEM_SNOWFLAKE_USER'),
#       3     account=os.getenv('SNOWFLAKE_ACCOUNT'),
#       4     warehouse=os.getenv('ANALYSIS_MED'),
#       5     authenticator='externalbrowser',
#       6 )
#       7 cur = conn.cursor()
#
# File ~/github/gokustats-back-end/venv-factor-models/lib/python3.9/site-packages/snowflake/connector/__init__.py:54, in Connect(**kwargs)
#      52 @wraps(SnowflakeConnection.__init__)
#      53 def Connect(**kwargs) -> SnowflakeConnection:
# ---> 54     return SnowflakeConnection(**kwargs)
#
# File ~/github/gokustats-back-end/venv-factor-models/lib/python3.9/site-packages/snowflake/connector/connection.py:654, in SnowflakeConnection.__init__(self, connection_name, connections_file_path, **kwargs)
# ...

# %%
# Sentiment Metric Backtest
